# %%
import numpy as np
import pandas as pd
import pymc3 as pm
import seaborn as sns
import theano
import warnings
from numpy.random import binomial, randn, uniform
from sklearn.model_selection import train_test_split
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %matplotlib inline

sns.set()
warnings.filterwarnings('ignore')

# %% [markdown]
# Generate data from
# $$y = \alpha_{c} + \beta_{c} \cdot x + \sigma \cdot \epsilon$$
#
# where $\epsilon \sim N(0,1)$ and $c \in \{0,1\}$
# let $\alpha_0 = 1, \alpha_1 = 1.25, \beta_0 = 1, \beta_1 = 1.25 \;$ and $\;\sigma = 0.75$

# %%
a0 ,a1, b0 , b1 , sigma = 1, 1.25, 1, 1.25, 0.75

# %%
n_samples = 1000

category = binomial(n=1, p=0.5, size=n_samples)
x = uniform(low=0, high=10, size=n_samples)

y = ((1 - category) * a0 + category * a1 + ((1 - category) * b0 + category * b1) * x + sigma * randn(n_samples))

model_data = pd.DataFrame({'y': y, 'x': x, 'category': category})

display(model_data.head())
if sns.__version__ == '0.9.0':
    sns.relplot(x='x', y='y', hue='category', data=model_data)
else:
    print('need update seaborn >= 0.9.0')
# Out:
#            y         x  category
# 0   5.251830  4.929709         0
# 1   5.433332  4.402846         0
# 2  10.720854  6.866178         1
# 3  12.844852  9.684535         1
# 4   2.723750  3.470877         0

# %% [markdown]
# pymc need transform datatype to theano

# %%
y_tensor = model_data.y.values#theano.shared(model_data.y.values.astype('float64'))
x_tensor = model_data.x.values#theano.shared(model_data.x.values.astype('float64'))
cat_tensor = model_data.category.values#theano.shared(model_data.category.values.astype('int32'))

# %% [markdown]
# prior setting
# $$y_i \sim N(\mu_i,\sigma^2) \\
# \mu_i =  \alpha_c + \beta_c \cdot x_i \\
# \alpha_0 \sim N(2,2^2) \\
# \alpha_1 \sim N(2,2^2) \\
# \beta_0 \sim N(2,2^2) \\
# \beta_1 \sim N(2,2^2) \\
# \sigma \sim invGamma(2,2)$$

# %%
with pm.Model() as model:
    a_prior = pm.Normal('a', mu=0, sd=2, shape=2)
    b_prior = pm.Normal('b', mu=0, sd=2, shape=2)
    sigma_prior = pm.InverseGamma('sigma',alpha=2,beta=2, shape=1)
    u_likelihood = a_prior[cat_tensor] + b_prior[cat_tensor] * x_tensor
    y_likelihood = pm.Normal('y', mu=u_likelihood, sd=sigma_prior, observed=y_tensor)

# %% [markdown]
# # MCMC sampling with No U-Turn Sampler (NUTS)

# %%
# %%time
iterations = 5000
with model:
    start = pm.find_MAP()
    step = pm.NUTS()
    nuts_trace = pm.sample(iterations, step, random_seed = 0,chains=1)
# Out:
# logp = -1,150.9, ||grad|| = 0.13266: 100%|███████████████████████████████████████████| 33/33 [00:00<00:00, 1372.09it/s]
# Sequential sampling (1 chains in 1 job)
# NUTS: [sigma, b, a]
# 100%|█████████████████████████████████████████████████████████████████████████████| 5500/5500 [00:11<00:00, 490.78it/s]
# Only one chain was sampled, this makes it impossible to run some convergence checks
# Wall time: 13.3 s

# %% [markdown]
# Summary the result

# %%
pm.traceplot(nuts_trace)
pm.summary(nuts_trace)
# Out:
#               mean        sd  mc_error   hpd_2.5  hpd_97.5
# a__0      1.021769  0.067560  0.001063  0.900182  1.165778
# a__1      1.272306  0.065671  0.001231  1.137693  1.394419
# b__0      0.989263  0.011612  0.000179  0.966593  1.011793
# b__1      1.250928  0.011726  0.000223  1.226745  1.272639
# sigma__0  0.761645  0.016807  0.000247  0.728757  0.794160

# %% [markdown]
# # Variational inference using ADVI

# %% [markdown]
# ADVI support minibatch so we use batches of 100 samples

# %%
map_tensor_batch = {y_tensor: pm.Minibatch(model_data.y.values, 100),
                    x_tensor: pm.Minibatch(model_data.x.values, 100),
                    cat_tensor: pm.Minibatch(model_data.category.values, 100)}

# %%
# %%time
with model:
    advi_fit = pm.fit(method=pm.ADVI(), n=30000, more_replacements=map_tensor_batch)
# Out:
# Average Loss = 128.79: 100%|███████████████████████████████████████████████████| 30000/30000 [00:19<00:00, 1503.41it/s]
# Finished [100%]: Average Loss = 128.78
# Wall time: 25.8 s

# %% [markdown]
# See the ELBO plot to confirm convergence

# %%
advi_elbo = pd.DataFrame(
    {'log-ELBO': -np.log(advi_fit.hist),
     'n': np.arange(advi_fit.hist.shape[0])})

sns.lineplot(y='log-ELBO', x='n', data=advi_elbo)

# %% [markdown]
# Plot the result

# %%
advi_trace = advi_fit.sample(10000)
display(pm.summary(advi_trace))
pm.traceplot(advi_trace)
# Out:
#               mean        sd  mc_error   hpd_2.5  hpd_97.5
# a__0      1.088571  0.122293  0.001220  0.850259  1.328905
# a__1      1.141259  0.123447  0.001214  0.898166  1.383901
# b__0      0.976459  0.021319  0.000203  0.936906  1.020120
# b__1      1.263092  0.021309  0.000202  1.221829  1.305023
# sigma__0  0.757534  0.060369  0.000549  0.640001  0.876215
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001763CC89828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001763CCA2DA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001763CCC24A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001763CCE1B70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001763CD052B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001763CD22940>]],
#       dtype=object)
